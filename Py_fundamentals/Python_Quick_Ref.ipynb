# %% [markdown]
# <a href="https://colab.research.google.com/github/FazilMSD7/Data-Analytics/blob/main/Py_fundamentals/Python_Quick_Ref.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###**🐍 Python Quick Reference — My Learning Progress (Data Engineering)**<br><br>
# ####1️⃣ **Core Concepts**
#
# * Keywords & Identifiers
#
# * Syntax and Dynamic Typing
#
# * Mutability vs Immutability
#
# * Code Readability & Reusability
#
# * Time Complexity (basic introduction)
#
# ####2️⃣ **Data Types & Structures**
#
# * Strings (counting, slicing, palindrome check, title case, etc.)
#
# * Lists (creation, indexing, built-in functions, mutability)
#
# * Tuples (ordered, immutable sequences)
#
# * Sets (unordered, unique elements, union/intersection/difference)
#
# * Dictionaries (key-value pairs, accessing, adding, deleting, nested dicts)
#
# ####3️⃣ **Operators**
#
# * Arithmetic Operators (+, -, *, /, //, %, **)
#
# * Assignment Operators (=, ==, +=, etc.)
#
# * Membership Operators (in, not in)
#
# ####4️⃣ **Functions**
#
# * Defining and Calling Functions
#
# * Positional, Keyword, and Default Arguments
#
# * *args (variable-length arguments)
#
# * Nested Functions
#
# * Lambda Functions
#
# * Higher-Order Functions (HOFs)
#
# * Built-in HOFs: map(), filter(), reduce()
#
# * Function Reusability & Dynamic Binding
#
# ####5️⃣ **OOP (Object-Oriented Programming)**
#
# * Concept of Objects and Classes
#
# * Encapsulation → Protect and control data inside a class
#
# * Inheritance → Reuse and extend functionality
#
# * Polymorphism → Same function name, different behaviors
#
# * Abstraction → Hide internal details, show essential parts
#
# * Creating and using Classes & Objects
#
# * Class variables, instance variables, and methods
#
# * Constructor (__init__) and self usage
#
# * Method overriding and inheritance chain
#
# * Using super() in child classes
#
# * Encapsulation using private variables (__var)
#
# * Polymorphism through method overriding and duck typing
#
# ####6️⃣ **File Handling**
#
# * Opening files using open() with different modes (r, w, a, r+)
#
# * Reading and writing text files
#
# * Using context manager (with open(...) as f)
#
# * Working with CSV files manually using splitlines() and loops
#
# ####7️⃣ **Exception Handling**
#
# * try, except, else, finally structure
#
# * Handling multiple exceptions
#
# * Using raise for custom exceptions
#
# * Defining and raising user-defined exceptions
#
# ####8️⃣ **Advanced Python Concepts**
#
# * Lambda functions → one-liner anonymous functions
#
# * Map, Filter, Reduce → applying functions over iterables
#
# Comprehensions → list, set, and dictionary comprehensions
#
# * enumerate() and zip() for iteration
#
# * *args and **kwargs
#
# * Docstrings and function documentation
#
# * Decorators (Intro) → wrapping functions dynamically
#
# * Working with built-in modules like os and sys
#
# ####9️⃣ **Miscellaneous Utilities**
#
# * Working with user-defined modules
#
# * Importing classes and functions across files
#
# * Understanding namespace and scope (global, local)
#
# * Basic understanding of memory handling (mutable vs immutable types)
#
# * Simple logging and debugging prints
