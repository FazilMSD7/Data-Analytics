# %% [markdown]
# <a href="https://colab.research.google.com/github/FazilMSD7/Data-Analytics/blob/main/Pandas/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###**Why Pandas?**
# Python library, built on NumPy to work with data's
# *  Import datasets(csv,excel,sql,json..)
# *  Data cleaning : Missing and Invalid values(age - 200)
# *  Size mutability : Easily delete rowns and cols
# *  Reshaping and Pivoting of datasets
# *  Efficient manipulation and extraction
# *  Statistical analysis

# %% [markdown]
# ###**Data Structures in Pandas**
# Data structure are collection of data types that provide best way of organizing item in terms of memory.
# * **Series** : <br>
# 1 dimensional DS, Only one col. and many row.<br>
# Only one datatype(int/string) -> Homogeneous <br>
# Size immutable (can't delete/add any row, It will create a new instead of updating older)
#
# * Dataframes : <br>
# 2 dimensional DS<, Many rows and colsbr>
# Multiple data types -> Hetrogenous<br>
# Size mutable

# %%
# !pip install pandas

# %%
import pandas as pd

# %% [markdown]
# **Series**

# %%
s = pd.Series([10,20,30,40])
s
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
s.values
# Out:
# array([10, 20, 30, 40])

# %%
s.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
s.name = 'numbers'
s
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# Name: numbers, dtype: int64

# %%
# Indexing
s[0:3]
# Out:
# 0    10
# 1    20
# 2    30
# Name: numbers, dtype: int64

# %%
# iloc -> location based indexing
s.iloc[3]

print(s.iloc[[1,2,3]])
# Out:
# 1    20
# 2    30
# 3    40
# Name: numbers, dtype: int64

# %%
s.name = 'Calories'
index = ['Apple','Banana','Strawberry','Mango']
s.index = index

s
# Out:
# Apple         10
# Banana        20
# Strawberry    30
# Mango         40
# Name: Calories, dtype: int64

# %%
s['Mango']
# Out:
# np.int64(40)

# %%
# loc -> label based indexing -> both start and stop are included
s.loc['Banana']
# Out:
# np.int64(20)

# %%
s.loc['Apple':'Strawberry']
# Out:
# Apple         10
# Banana        20
# Strawberry    30
# Name: Calories, dtype: int64

# %%
# Series in Dict

d = {'Apple':0.3,'Kiwi':1.1,'Guava':2.6,'Avacado':2.0,'Banana':1.1}
s2 = pd.Series(d)
s2.name = 'Protein'
s2
# Out:
# Apple      0.3
# Kiwi       1.1
# Guava      2.6
# Avacado    2.0
# Banana     1.1
# Name: Protein, dtype: float64

# %%
# Conditional selection

s2>1
# Out:
# Apple      False
# Kiwi        True
# Guava       True
# Avacado     True
# Banana      True
# Name: Protein, dtype: bool

# %%
s2[s2>1]
# Out:
# Kiwi       1.1
# Guava      2.6
# Avacado    2.0
# Banana     1.1
# Name: Protein, dtype: float64

# %%
# logical operators (AND/OR/NOT)

s2[(s2>0.5) & (s2<2)]
# Out:
# Kiwi      1.1
# Banana    1.1
# Name: Protein, dtype: float64

# %%
s2[(s2>0.5) | (s2<2)]
# Out:
# Apple      0.3
# Kiwi       1.1
# Guava      2.6
# Avacado    2.0
# Banana     1.1
# Name: Protein, dtype: float64

# %%
s2[~(s2>1)]
# Out:
# Apple    0.3
# Name: Protein, dtype: float64

# %%
# Modifing series

s2['Kiwi'] = 2.1
s2
# Out:
# Apple      0.3
# Kiwi       2.1
# Guava      2.6
# Avacado    2.0
# Banana     1.1
# Name: Protein, dtype: float64

# %% [markdown]
# **Dataframe**

# %%
data = {
    "name": ["Alice", "Tessa", "Julie", "Loki", "Adam", "Ibn"],
    "age": [23, 43, 29, 35, None , 31],
    "department": ["HR", "IT", "Finance", "Marketing", "Operations", "IT"],
    "salary": [24000, 34000, 28000, 30000, 32000, 52000]
}

s3 = pd.Series(data)  #while using Series, it's bcz Series is one dimensional
s3
# Out:
# name                [Alice, Tessa, Julie, Loki, Adam, Ibn]
# age                             [23, 43, 29, 35, None, 31]
# department    [HR, IT, Finance, Marketing, Operations, IT]
# salary          [24000, 34000, 28000, 30000, 32000, 52000]
# dtype: object

# %%
df = pd.DataFrame(data)
df
# Out:
#     name   age  department  salary
# 0  Alice  23.0          HR   24000
# 1  Tessa  43.0          IT   34000
# 2  Julie  29.0     Finance   28000
# 3   Loki  35.0   Marketing   30000
# 4   Adam   NaN  Operations   32000
# 5    Ibn  31.0          IT   52000

# %%
# head() -> starting values
df.head(3)
# Out:
#     name   age department  salary
# 0  Alice  23.0         HR   24000
# 1  Tessa  43.0         IT   34000
# 2  Julie  29.0    Finance   28000

# %%
# tail() -> ending values
df.tail(3)
# Out:
#    name   age  department  salary
# 3  Loki  35.0   Marketing   30000
# 4  Adam   NaN  Operations   32000
# 5   Ibn  31.0          IT   52000

# %%
# iloc and loc
df.iloc[1:3]
# Out:
#     name   age department  salary
# 1  Tessa  43.0         IT   34000
# 2  Julie  29.0    Finance   28000

# %%
df.iloc[1:3, :2]  #rows, col
# Out:
#     name   age
# 1  Tessa  43.0
# 2  Julie  29.0

# %%
df.loc[1:3,["name","department"]]
# Out:
#     name department
# 1  Tessa         IT
# 2  Julie    Finance
# 3   Loki  Marketing

# %%
df[['name','department','age']]
# Out:
#     name  department   age
# 0  Alice          HR  23.0
# 1  Tessa          IT  43.0
# 2  Julie     Finance  29.0
# 3   Loki   Marketing  35.0
# 4   Adam  Operations   NaN
# 5    Ibn          IT  31.0

# %%
# remove null value (temp.) -> to remove permanently use 'inplace = True'
df.drop('age',axis = 1)
# Out:
#     name  department  salary
# 0  Alice          HR   24000
# 1  Tessa          IT   34000
# 2  Julie     Finance   28000
# 3   Loki   Marketing   30000
# 4   Adam  Operations   32000
# 5    Ibn          IT   52000

# %%
df
# Out:
#     name   age  department  salary
# 0  Alice  23.0          HR   24000
# 1  Tessa  43.0          IT   34000
# 2  Julie  29.0     Finance   28000
# 3   Loki  35.0   Marketing   30000
# 4   Adam   NaN  Operations   32000
# 5    Ibn  31.0          IT   52000

# %%
df.drop('age',axis = 1, inplace = True) #inplace removes permanently
df
# Out:
#     name  department  salary
# 0  Alice          HR   24000
# 1  Tessa          IT   34000
# 2  Julie     Finance   28000
# 3   Loki   Marketing   30000
# 4   Adam  Operations   32000
# 5    Ibn          IT   52000

# %%
df.shape  #rows, col
# Out:
# (6, 3)

# %%
df.info() #information
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        6 non-null      object
#  1   department  6 non-null      object
#  2   salary      6 non-null      int64
# dtypes: int64(1), object(2)
# memory usage: 276.0+ bytes

# %%
df.describe() #basic information
# Out:
#              salary
# count      6.000000
# mean   33333.333333
# std     9770.704512
# min    24000.000000
# 25%    28500.000000
# 50%    31000.000000
# 75%    33500.000000
# max    52000.000000

# %%
# Broadcasting -> automatically applying an op. to all elements

df['salary'] = df['salary'] + 5000
df
# Out:
#     name  department  salary
# 0  Alice          HR   29000
# 1  Tessa          IT   39000
# 2  Julie     Finance   33000
# 3   Loki   Marketing   35000
# 4   Adam  Operations   37000
# 5    Ibn          IT   57000

# %%
# renaming columns

df.rename(columns= {'department' : 'dept'}, inplace=True)
df
# Out:
#     name        dept  salary
# 0  Alice          HR   29000
# 1  Tessa          IT   39000
# 2  Julie     Finance   33000
# 3   Loki   Marketing   35000
# 4   Adam  Operations   37000
# 5    Ibn          IT   57000

# %%
df.index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
# set index range
df.index = range(1,len(df)+1)
df
# Out:
#     name        dept  salary
# 1  Alice          HR   29000
# 2  Tessa          IT   39000
# 3  Julie     Finance   33000
# 4   Loki   Marketing   35000
# 5   Adam  Operations   37000
# 6    Ibn          IT   57000

# %%
# set_index() -> modify index with col.
df.set_index('dept')
df
# Out:
#     name        dept  salary
# 1  Alice          HR   29000
# 2  Tessa          IT   39000
# 3  Julie     Finance   33000
# 4   Loki   Marketing   35000
# 5   Adam  Operations   37000
# 6    Ibn          IT   57000

# %%
df.set_index('dept',inplace=True)
df
# Out:
#              name  salary
# dept
# HR          Alice   29000
# IT          Tessa   39000
# Finance     Julie   33000
# Marketing    Loki   35000
# Operations   Adam   37000
# IT            Ibn   57000

# %%
df.loc['IT']
# Out:
#        name  salary
# dept
# IT    Tessa   39000
# IT      Ibn   57000

# %%
df.iloc[1:3]
# Out:
#           name  salary
# dept
# IT       Tessa   39000
# Finance  Julie   33000

# %%
# rest_index()
df.reset_index(inplace=True)
df
# Out:
#          dept   name  salary
# 0          HR  Alice   29000
# 1          IT  Tessa   39000
# 2     Finance  Julie   33000
# 3   Marketing   Loki   35000
# 4  Operations   Adam   37000
# 5          IT    Ibn   57000

# %%
# unique -> to get unique value in col
df['dept'].unique()
# Out:
# array(['HR', 'IT', 'Finance', 'Marketing', 'Operations'], dtype=object)

# %%
# valuecounts -> to know count of each col
df['dept'].value_counts()
# Out:
# dept
# IT            2
# HR            1
# Finance       1
# Marketing     1
# Operations    1
# Name: count, dtype: int64

# %%
df['promoted_salary'] = df['salary'] * 0.10 + df['salary']
df
# Out:
#          dept   name  salary  promoted_salary
# 0          HR  Alice   29000          31900.0
# 1          IT  Tessa   39000          42900.0
# 2     Finance  Julie   33000          36300.0
# 3   Marketing   Loki   35000          38500.0
# 4  Operations   Adam   37000          40700.0
# 5          IT    Ibn   57000          62700.0

# %% [markdown]
# ### Data Cleaning
#
#
# 1.  To get rid of missing values :
#   * Get rid of those -> dropna(), isnull()
#   * By filling those -> fillna() -> forwardfill, backwardfill
#
# 2.  Replace and Rename values
#
# 3.  Duplicate data : duplicated(), drop_duplicates()
#
# 4. Invalid values :
#   * int_values : apply(lambda) -> eg: apply(lambda x : x/10 if x> 45000 else x)
#   * string_values : df[['fname','lname']] = df['name'].str.split('_', expand = True)

# %%
# update value of any field
index = data['name'].index('Adam')
df['promoted_salary'][index] = None
df
# Out:
# /tmp/ipython-input-3801749444.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['promoted_salary'][index] = None
# /tmp/ipython-input-3801749444.py:3: SettingWithCopyWarning:
# ...

# %%
# to find total no. of null values in each col/field
df.isnull().sum()
# Out:
# dept               0
# name               0
# salary             0
# promoted_salary    1
# dtype: int64

# %%
# to remove row which has null values
df.dropna()

df.dropna(how = 'any')  # by default this will be performed inside dropna()
# Out:
#         dept   name  salary  promoted_salary
# 0         HR  Alice   29000          31900.0
# 1         IT  Tessa   39000          42900.0
# 2    Finance  Julie   33000          36300.0
# 3  Marketing   Loki   35000          38500.0
# 5         IT    Ibn   57000          62700.0

# %%
df  # org. not replaced bcz not used inplace = True
# Out:
#          dept   name  salary  promoted_salary
# 0          HR  Alice   29000          31900.0
# 1          IT  Tessa   39000          42900.0
# 2     Finance  Julie   33000          36300.0
# 3   Marketing   Loki   35000          38500.0
# 4  Operations   Adam   37000              NaN
# 5          IT    Ibn   57000          62700.0

# %%
# dropna(how = 'all') -> row which has all null value. Eg. If 3rd row : Julie has all null values it will be dropped
df.dropna(how = 'all')
# Out:
#          dept   name  salary  promoted_salary
# 0          HR  Alice   29000          31900.0
# 1          IT  Tessa   39000          42900.0
# 2     Finance  Julie   33000          36300.0
# 3   Marketing   Loki   35000          38500.0
# 4  Operations   Adam   37000              NaN
# 5          IT    Ibn   57000          62700.0

# %%
# to fill those null values

df.fillna(0)
# Out:
#          dept   name  salary  promoted_salary
# 0          HR  Alice   29000          31900.0
# 1          IT  Tessa   39000          42900.0
# 2     Finance  Julie   33000          36300.0
# 3   Marketing   Loki   35000          38500.0
# 4  Operations   Adam   37000              0.0
# 5          IT    Ibn   57000          62700.0

# %%
# it will be replaced by mean of that col/field
df['promoted_salary'].fillna(df['promoted_salary'].mean())
# Out:
# 0    31900.0
# 1    42900.0
# 2    36300.0
# 3    38500.0
# 4    42460.0
# 5    62700.0
# Name: promoted_salary, dtype: float64

# %%
# fill with median()
df['promoted_salary'].fillna(df['promoted_salary'].median())
# Out:
# 0    31900.0
# 1    42900.0
# 2    36300.0
# 3    38500.0
# 4    38500.0
# 5    62700.0
# Name: promoted_salary, dtype: float64

# %%
# forwardfill -> ffill()
df['promoted_salary'].fillna(method = 'ffill')
# Out:
# /tmp/ipython-input-6413611.py:2: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['promoted_salary'].fillna(method = 'ffill')
# 0    31900.0
# 1    42900.0
# 2    36300.0
# 3    38500.0
# 4    38500.0
# 5    62700.0
# Name: promoted_salary, dtype: float64

# %%
# backwardfill -> bfill()
df['promoted_salary'].fillna(method = 'bfill')
# Out:
# /tmp/ipython-input-986084568.py:2: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['promoted_salary'].fillna(method = 'bfill')
# 0    31900.0
# 1    42900.0
# 2    36300.0
# 3    38500.0
# 4    62700.0
# 5    62700.0
# Name: promoted_salary, dtype: float64

# %%
df
# Out:
#          dept   name  salary  promoted_salary
# 0          HR  Alice   29000          31900.0
# 1          IT  Tessa   39000          42900.0
# 2     Finance  Julie   33000          36300.0
# 3   Marketing   Loki   35000          38500.0
# 4  Operations   Adam   37000              NaN
# 5          IT    Ibn   57000          62700.0

# %%
# replace()
df['name'] = df['name'].replace('Loki','Lokah') # or use inplace instead of assign variable..
df
# Out:
#          dept   name  salary  promoted_salary
# 0          HR  Alice   29000          31900.0
# 1          IT  Tessa   39000          42900.0
# 2     Finance  Julie   33000          36300.0
# 3   Marketing  Lokah   35000          38500.0
# 4  Operations   Adam   37000              NaN
# 5          IT    Ibn   57000          62700.0

# %%
# just changing values to perform duplicate op.   # here .index[0] -> picks one and only value, if we have many use index.tolist()

alice_index = df[df['name'] == 'Alice'].index[0]
ibn_index = df[df['name'] == 'Ibn'].index[0]

df.loc[ibn_index] = df.loc[alice_index]
df
# Out:
#          dept   name  salary  promoted_salary
# 0          HR  Alice   29000          31900.0
# 1          IT  Tessa   39000          42900.0
# 2     Finance  Julie   33000          36300.0
# 3   Marketing  Lokah   35000          38500.0
# 4  Operations   Adam   37000              NaN
# 5          HR  Alice   29000          31900.0

# %%
# here we have Alice and row duplicated

df_dup = df[df.duplicated()]

df_dup = df[df.duplicated(keep = 'first')]    # by default it works like this inside
df_dup
# Out:
#   dept   name  salary  promoted_salary
# 5   HR  Alice   29000          31900.0

# %%
df_dup = df[df.duplicated(keep = 'last')]
df_dup
# Out:
#   dept   name  salary  promoted_salary
# 0   HR  Alice   29000          31900.0

# %%
# to drop duplicate
df = df.drop_duplicates()
df
# Out:
#          dept   name  salary  promoted_salary
# 0          HR  Alice   29000          31900.0
# 1          IT  Tessa   39000          42900.0
# 2     Finance  Julie   33000          36300.0
# 3   Marketing  Lokah   35000          38500.0
# 4  Operations   Adam   37000              NaN

# %% [markdown]
# ###Filtering & Transformation
#
# *   Conditional filtering(df[df['col']>10])
# *   Applying functions : apply, lambda, map, applymap<br><br>
#
#     apply : for specific col -> data['col_name].apply(fn)<br> if axis = 0 : for each column, if axis = 1 : for each row<br><br>
#     lambda : for conditional apply ->  data['col_name].apply(lambda x:x*2) / .map(lambda x:x**2)...<br><br>
#     map : for only series(not for df) and specific col, also pass dict. -> data['col_name].map(str.upper)<br><br>
#     applymap : for whole dataframe/series -> data.applymap(fn)

# %% [markdown]
# Trick to remember<br>
# ![image.png](data:image/png;base64,...)

# %%
# invalid values
# Lambda -> python(applies for all)

#apply()
df['promoted_salary'] = df['promoted_salary'].apply(lambda x : x/10 if x> 45000 else x)
df
# Out:
# /tmp/ipython-input-3883057444.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['promoted_salary'] = df['promoted_salary'].apply(lambda x : x/10 if x> 45000 else x)
#          dept   name  salary  promoted_salary
# 0          HR  Alice   29000          31900.0
# 1          IT  Tessa   39000          42900.0
# 2     Finance  Julie   33000          36300.0
# 3   Marketing  Lokah   35000          38500.0
# 4  Operations   Adam   37000              NaN

# %%
#Invalid String functions

# creating sample data to perform this

data1 = {
    "name": ["alice_fernandez", "tessa_james", "john_wick", "adam_smith", "ibn_khalid"],
    "age": [23, 30, None, 35, 40]
}

sample_df = pd.DataFrame(data1)
sample_df[['fname','lname']] = sample_df['name'].str.split('_',expand = True)
sample_df
# Out:
#               name   age  fname      lname
# 0  alice_fernandez  23.0  alice  fernandez
# 1      tessa_james  30.0  tessa      james
# 2        john_wick   NaN   john       wick
# 3       adam_smith  35.0   adam      smith
# 4       ibn_khalid  40.0    ibn     khalid

# %%
# map()
def upper(x):
  return x.upper()

sample_df['name'] = sample_df['name'].map(upper)
sample_df
# Out:
#               name   age  fname      lname
# 0  ALICE_FERNANDEZ  23.0  alice  fernandez
# 1      TESSA_JAMES  30.0  tessa      james
# 2        JOHN_WICK   NaN   john       wick
# 3       ADAM_SMITH  35.0   adam      smith
# 4       IBN_KHALID  40.0    ibn     khalid

# %%
# apply through python 'def' instead of lambda

def multiply_age(x):
  return x*2


sample_df['age'] = sample_df['age'].apply(multiply_age)
sample_df
# Out:
#               name   age  fname      lname
# 0  ALICE_FERNANDEZ  46.0  alice  fernandez
# 1      TESSA_JAMES  60.0  tessa      james
# 2        JOHN_WICK   NaN   john       wick
# 3       ADAM_SMITH  70.0   adam      smith
# 4       IBN_KHALID  80.0    ibn     khalid

# %%
# apply and lambda to bring back deafault age

sample_df['age'] = sample_df['age'].apply(lambda x:x/2)
sample_df
# Out:
#               name   age  fname      lname
# 0  ALICE_FERNANDEZ  23.0  alice  fernandez
# 1      TESSA_JAMES  30.0  tessa      james
# 2        JOHN_WICK   NaN   john       wick
# 3       ADAM_SMITH  35.0   adam      smith
# 4       IBN_KHALID  40.0    ibn     khalid

# %%
# applymap : for whole dataframe/series
def capitalize(x):
  return str(x).capitalize()

sample_df.applymap(capitalize)
# Out:
# /tmp/ipython-input-3479574482.py:5: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   sample_df.applymap(capitalize)
#               name   age  fname      lname
# 0  Alice_fernandez  23.0  Alice  Fernandez
# 1      Tessa_james  30.0  Tessa      James
# 2        John_wick   Nan   John       Wick
# 3       Adam_smith  35.0   Adam      Smith
# 4       Ibn_khalid  40.0    Ibn     Khalid

# %%
# if these fn's should apply for Null values use (na_action='ignore') for all map, apply, applymap
def lower(x):
  return str(x).lower()

sample_df.applymap(lower, na_action='ignore')
# Out:
# /tmp/ipython-input-2801013866.py:5: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   sample_df.applymap(lower, na_action='ignore')
#               name   age  fname      lname
# 0  alice_fernandez  23.0  alice  fernandez
# 1      tessa_james  30.0  tessa      james
# 2        john_wick   NaN   john       wick
# 3       adam_smith  35.0   adam      smith
# 4       ibn_khalid  40.0    ibn     khalid

# %% [markdown]
# ###Joins and Merges
#
# *   merge() - SQL - style joins
# *   concat() - appending dataframes
# *   diff. btw merge and join
#
#
# ![Python-Pandas-Join.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Merge : combine DataFrames using common columns or keys (like SQL joins)<br>
#
# *   df = pd.merge(df1, df2, on="id", how="inner")
#
# Joins : merges DataFrames using their index by default.
#
# *   df = df3.join(df4, how="inner")

# %% [markdown]
# concat() vs merge() vs join() <br>
# ![image.png](data:image/png;base64,...)

# %%
# Joins and Merges
department_info = {
     "dept": ["HR", "IT", "Finance", "Marketing"],
    "location": ["New York", "London", "Paris", "Berlin"],
    "manager": ["M1", "M2", "M3", "M4"]
}


df2 = pd.DataFrame(department_info)
df2
# Out:
#         dept  location manager
# 0         HR  New York      M1
# 1         IT    London      M2
# 2    Finance     Paris      M3
# 3  Marketing    Berlin      M4

# %%
df
# Out:
#          dept   name  salary  promoted_salary
# 0          HR  Alice   29000          31900.0
# 1          IT  Tessa   39000          42900.0
# 2     Finance  Julie   33000          36300.0
# 3   Marketing  Lokah   35000          38500.0
# 4  Operations   Adam   37000              NaN

# %% [markdown]
# **Concat** : pd.concat()
#
# *  Used to stack/attach DataFrames vertically (axis=0) or horizontally (axis=1).
#
# *  Does not care about column values unless you align manually.
#
# *  More like “gluing” DataFrames together.

# %%
# concat : to merge both tables/datasets

pd.concat([df,df2])
# Out:
#          dept   name   salary  promoted_salary  location manager
# 0          HR  Alice  29000.0          31900.0       NaN     NaN
# 1          IT  Tessa  39000.0          42900.0       NaN     NaN
# 2     Finance  Julie  33000.0          36300.0       NaN     NaN
# 3   Marketing  Lokah  35000.0          38500.0       NaN     NaN
# 4  Operations   Adam  37000.0              NaN       NaN     NaN
# 0          HR    NaN      NaN              NaN  New York      M1
# 1          IT    NaN      NaN              NaN    London      M2
# 2     Finance    NaN      NaN              NaN     Paris      M3
# 3   Marketing    NaN      NaN              NaN    Berlin      M4

# %%
pd.concat([df,df2], axis =1)  #axis = 0 default(rows), axis = 1(cols)
# Out:
#          dept   name  salary  promoted_salary       dept  location manager
# 0          HR  Alice   29000          31900.0         HR  New York      M1
# 1          IT  Tessa   39000          42900.0         IT    London      M2
# 2     Finance  Julie   33000          36300.0    Finance     Paris      M3
# 3   Marketing  Lokah   35000          38500.0  Marketing    Berlin      M4
# 4  Operations   Adam   37000              NaN        NaN       NaN     NaN

# %% [markdown]
# **Merge** : pd.merge()
#
# * Used to combine DataFrames based on keys/columns, just like SQL joins.
#
# * You control how rows match using the on or left_on/right_on parameters.
#
# * Supports join types: inner, left, right, outer.

# %%
pd.merge(df,df2, on = 'dept')
# Out:
#         dept   name  salary  promoted_salary  location manager
# 0         HR  Alice   29000          31900.0  New York      M1
# 1         IT  Tessa   39000          42900.0    London      M2
# 2    Finance  Julie   33000          36300.0     Paris      M3
# 3  Marketing  Lokah   35000          38500.0    Berlin      M4

# %%
pd.merge(df,df2, on= 'dept', how = 'outer')
# Out:
#          dept   name  salary  promoted_salary  location manager
# 0     Finance  Julie   33000          36300.0     Paris      M3
# 1          HR  Alice   29000          31900.0  New York      M1
# 2          IT  Tessa   39000          42900.0    London      M2
# 3   Marketing  Lokah   35000          38500.0    Berlin      M4
# 4  Operations   Adam   37000              NaN       NaN     NaN

# %% [markdown]
# **Join** : pd.join()
#
# *   It uses the index (row labels) to connect DataFrames by default.
# *   If two tables have matching row labels like 0, 1, 2…(ID's) then join combines them easily.
# *   To use join(), set index first:
# *   index ≠ column

# %%
# set index first
df_1 = df.set_index('dept')
df_2 = df2.set_index('dept')

df_1.join(df_2, how='inner')
# Out:
#             name  salary  promoted_salary  location manager
# dept
# HR         Alice   29000          31900.0  New York      M1
# IT         Tessa   39000          42900.0    London      M2
# Finance    Julie   33000          36300.0     Paris      M3
# Marketing  Lokah   35000          38500.0    Berlin      M4

# %%
df2
# Out:
#            location manager
# dept
# HR         New York      M1
# IT           London      M2
# Finance       Paris      M3
# Marketing    Berlin      M4

# %%
print(df2.index)
print(df2.columns)

print(df.index)
print(df.columns)
# Out:
# Index(['HR', 'IT', 'Finance', 'Marketing'], dtype='object', name='dept')
# Index(['location', 'manager'], dtype='object')
# Index([0, 1, 2, 3, 4], dtype='int64')
# Index(['dept', 'name', 'salary', 'promoted_salary'], dtype='object')

# %%
df.join(df2, on='dept')

# df.index does not need to match df2.index if you use on='dept'.

# Pandas will look up df2 using the values in df['dept'].
# Out:
#          dept   name  salary  promoted_salary  location manager
# 0          HR  Alice   29000          31900.0  New York      M1
# 1          IT  Tessa   39000          42900.0    London      M2
# 2     Finance  Julie   33000          36300.0     Paris      M3
# 3   Marketing  Lokah   35000          38500.0    Berlin      M4
# 4  Operations   Adam   37000              NaN       NaN     NaN

# %% [markdown]
# **Importing File**

# %%
data = pd.read_csv('customer_data.csv')
data
# Out:
#    customer_id  age  annual_income spending_score        Segment  OrderValue  \
# 0            1   25          40000             30              0        1200
# 1            2   34          50000             50              1        2500
# 2            3   45          60000             na              2        4500
# 3            4   23          30000             20              0         600
# 4            5   41          70000             80  not available        5600
#
#          Date
# 0  11-09-2025
# 1  12-09-2025
# 2  19-05-2025
# 3  24-01-2025
# 4  05-04-2025

# %%
data.shape
# Out:
# (5, 7)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   customer_id     5 non-null      int64
#  1   age             5 non-null      int64
#  2   annual_income   5 non-null      int64
#  3   spending_score  5 non-null      object
#  4   Segment         5 non-null      object
#  5   OrderValue      5 non-null      int64
#  6   Date            5 non-null      object
# dtypes: int64(4), object(3)
# memory usage: 412.0+ bytes

# %%
# header : to add header (default - index)
data = pd.read_csv('customer_data.csv',header=None)
data
# Out:
#              0    1              2               3              4           5  \
# 0  customer_id  age  annual_income  spending_score        Segment  OrderValue
# 1            1   25          40000              30              0        1200
# 2            2   34          50000              50              1        2500
# 3            3   45          60000              na              2        4500
# 4            4   23          30000              20              0         600
# 5            5   41          70000              80  not available        5600
#
#             6
# 0        Date
# 1  11-09-2025
# 2  12-09-2025
# 3  19-05-2025
# 4  24-01-2025
# 5  05-04-2025

# %%
# skiprows : to skip any particular row
data = pd.read_csv('customer_data.csv',skiprows=1)
data
# Out:
#    1  25  40000  30              0  1200  11-09-2025
# 0  2  34  50000  50              1  2500  12-09-2025
# 1  3  45  60000  na              2  4500  19-05-2025
# 2  4  23  30000  20              0   600  24-01-2025
# 3  5  41  70000  80  not available  5600  05-04-2025

# %%
# add header by names
data = pd.read_csv('customer_data.csv',header=None, names=['customer_id','age','annual_income','spending_score','Segment','OrderValue','Date'])
data
# Out:
#    customer_id  age  annual_income  spending_score        Segment  OrderValue  \
# 0  customer_id  age  annual_income  spending_score        Segment  OrderValue
# 1            1   25          40000              30              0        1200
# 2            2   34          50000              50              1        2500
# 3            3   45          60000              na              2        4500
# 4            4   23          30000              20              0         600
# 5            5   41          70000              80  not available        5600
#
#          Date
# 0        Date
# 1  11-09-2025
# 2  12-09-2025
# 3  19-05-2025
# 4  24-01-2025
# 5  05-04-2025

# %%
# read limited rows
data = pd.read_csv('customer_data.csv',nrows=3)
data
# Out:
#    customer_id  age  annual_income spending_score  Segment  OrderValue  \
# 0            1   25          40000             30        0        1200
# 1            2   34          50000             50        1        2500
# 2            3   45          60000             na        2        4500
#
#          Date
# 0  11-09-2025
# 1  12-09-2025
# 2  19-05-2025

# %%
# replace null values into NaN
data = pd.read_csv('customer_data.csv', na_values=['not available','na'])
data
# Out:
#    customer_id  age  annual_income  spending_score  Segment  OrderValue  \
# 0            1   25          40000            30.0      0.0        1200
# 1            2   34          50000            50.0      1.0        2500
# 2            3   45          60000             NaN      2.0        4500
# 3            4   23          30000            20.0      0.0         600
# 4            5   41          70000            80.0      NaN        5600
#
#          Date
# 0  11-09-2025
# 1  12-09-2025
# 2  19-05-2025
# 3  24-01-2025
# 4  05-04-2025

# %%
# change dtype of any : eg. date(object) -> date(date)

data['Date'] = pd.to_datetime(data['Date'], format='%d-%m-%Y')

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   customer_id     5 non-null      int64
#  1   age             5 non-null      int64
#  2   annual_income   5 non-null      int64
#  3   spending_score  4 non-null      float64
#  4   Segment         4 non-null      float64
#  5   OrderValue      5 non-null      int64
#  6   Date            5 non-null      datetime64[ns]
# dtypes: datetime64[ns](1), float64(2), int64(4)
# memory usage: 412.0 bytes

# %%
# create new csv/write to csv using exising tables/files : df.to_csv
data.to_csv('newPd.csv',index=False)

data.to_csv('newPd2.csv',columns=['age','annual_income'], index=False)

# %%
# converter : to replace values in excel file

def convert_nameCell(x):
  if x == 'na':
    return None
  return x

def convert_salaryCell(x):
  if x == 'na':
    return None
  return x

ex = pd.read_excel('sample_employees.xlsx',converters={
    'Name' : convert_nameCell,
    'Salary' : convert_salaryCell
})
ex
# Out:
#    Employee_ID     Name Department  Age   Salary
# 0          101    Alice         IT   25  50000.0
# 1          102     None         HR   29  55000.0
# 2          103  Charlie    Finance   31      NaN
# 3          104    David  Marketing   27  52000.0

# %%
# ExcelWriter() class -> to write multiple dataframes to excel
stocks_df = pd.DataFrame({
    "Date": ["2025-10-01", "2025-10-02", "2025-10-03", "2025-10-04", "2025-10-05"],
    "Company": ["Apple", "Microsoft", "Google", "Amazon", "Tesla"],
    "Volume": [52000000, 41000000, 38000000, 29500000, 60000000]
})

weather_df = pd.DataFrame({
    "Date": ["2025-10-01", "2025-10-02", "2025-10-03", "2025-10-04", "2025-10-05"],
    "City": ["New York", "Los Angeles", "Chicago", "Houston", "Miami"],
    "Temperature": [22, 25, 18, 30, 28],
})

with pd.ExcelWriter('stocks_weather.xlsx') as writer:
  stocks_df.to_excel(writer, sheet_name='stocks')
  weather_df.to_excel(writer, sheet_name='weather')
